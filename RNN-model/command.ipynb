# %%
import os
import sys
import numpy as np
# !echo $PATH
# sys.path
os.getcwd()
# Out:
# '/Users/xun/RRS/Model/RNN'

# %%
# %run -i train.py -d ks-cooks-1y -b 64 --max_length 60 --progress 5000 --min_iter 50000 --max_iter 200000
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/xun/Library/Python/3.7/lib/python/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Opening file (1)
# WARNING:tensorflow:From /Users/xun/Library/Python/3.7/lib/python/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# mini_batch generator iteration = 0 cost: 7.2979336 1567873376.0407481
# mini_batch generator iteration = 1 cost: 7.2855105 1567873376.118167
# mini_batch generator iteration = 2 cost: 9.646502 1567873376.187652
# mini_batch generator iteration = 3 cost: 8.273589 1567873376.264122
# mini_batch generator iteration = 4 cost: 7.289919 1567873376.3371918
# ...

# %%
# %run test.py -d ks-cooks-1y -b 32 --max_length 60 -i 2406.162

# %%
# %run -i test.py -d ks-cooks-1y -b 32 --max_length 30 --r_emb 100 --r_l 100 -i 1883.21

# %%
s = np.random.uniform(0, 60, 10)
s
# Out:
# array([ 8.68614571,  2.05493222, 23.80688013, 48.48734771, 59.4311464 ,
#        11.47012736, 14.98508504,  5.03071724, 33.94912682, 41.01026571])

# %%
import random
random.randrange(0, 60, 10)
# Out:
# 10

# %%
random.randrange(0, 60, 10)
# Out:
# 50

# %%
for i in range(0, 55, 10):
    print (i)
# Out:
# 0
# 10
# 20
# 30
# 40
# 50

# %%
a =  random.sample(range(0,58,10),6)

# %%
a
# Out:
# [30, 40, 10, 0, 50, 20]

# %%
# %run -i train.py -d ks-cooks-1y -b 32 --max_length 60 --r_emb 100 --r_l 100 --progress 158 --min_iter 50 --max_iter 4
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /Users/xun/Library/Python/3.7/lib/python/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/xun/Library/Python/3.7/lib/python/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
# /usr/local/lib/python3.7/site-packages/keras/engine/training_generator.py:47: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# Opening file (1)
# Opening file (1)
# Opening file (1)
# ...

# %%
from time import time
int(str(time())[-3:])
# Out:
# 507

# %%
print(time())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/RRS/Model/RNN/train.py in <module>
# ----> 1 print(time()[0:3])
#
# TypeError: 'float' object is not subscriptable
